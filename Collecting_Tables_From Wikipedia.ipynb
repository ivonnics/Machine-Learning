# %% [markdown]
# <a href="https://colab.research.google.com/github/ivonnics/Machine-Learning/blob/master/Collecting_Tables_From%20Wikipedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#Load data
url = "https://en.wikipedia.org/wiki/List_of_countries_by_number_of_military_and_paramilitary_personnel"
#url = "C:\\Users\\ivonnics\\Documents\\JOSE LUIS\\Cursos Cursera\\Machine Learning\\CJD2.csv"
dataset = pd.read_html(url)
Tabla=dataset[0]
Tabla.head(20)
# Out:
#        0                           1                2                 3  \
# 0   Flag                     Country  Active military  Reserve military
# 1    NaN              Afghanistan[1]           174300                 0
# 2    NaN                  Albania[2]             8000                 0
# 3    NaN                  Algeria[3]           130000            150000
# 4    NaN                   Angola[4]           107000                 0
# 5    NaN      Antigua and Barbuda[5]              180                80
# 6    NaN                Argentina[6]            74200                 0
# 7    NaN  Armenia[7][Note 1][Note 2]            44800            210000
# 8    NaN                Australia[8]            57800             21100
# 9    NaN              Austria[9][10]            22400            152200
# 10   NaN              Azerbaijan[11]            66950            300000
# 11   NaN                 Bahamas[12]             1300                 0
# ...

# %%
df=Tabla
df = df.drop(0, 1)
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df['Country'] = df['Country'].str.replace("\[.*$", '')
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (172, 7)
# 0
# Country                    object
# Active military            object
# Reserve military           object
# Paramilitary               object
# Total                      object
# Per 1000 capita(total)     object
# Per 1000 capita(active)    object
# dtype: object
# 0              Country Active military Reserve military Paramilitary   Total  \
# 1          Afghanistan          174300                0       148700  323000
# 2              Albania            8000                0          500    8500
# 3              Algeria          130000           150000       187200  467200
# 4               Angola          107000                0        10000  117000
# 5  Antigua and Barbuda             180               80            0     260
#
# 0 Per 1000 capita(total) Per 1000 capita(active)
# 1                    9.5                     5.1
# 2                    2.8                     2.6
# 3                   11.4                     3.2
# ...

# %%
#Load data
url = "https://meta.wikimedia.org/wiki/List_of_countries_by_regional_classification"
#url = "C:\\Users\\ivonnics\\Documents\\JOSE LUIS\\Cursos Cursera\\Machine Learning\\CJD2.csv"
dataset = pd.read_html(url)
Tabla=dataset[0]
print(Tabla.shape)
print(Tabla.dtypes)
Tabla.head(20)
# Out:
# (259, 3)
# 0    object
# 1    object
# 2    object
# dtype: object
#                          0                    1             2
# 0                  Country               Region  Global South
# 1                  Andorra               Europe  Global North
# 2     United Arab Emirates          Arab States  Global South
# 3              Afghanistan       Asia & Pacific  Global South
# 4      Antigua and Barbuda  South/Latin America  Global South
# 5                 Anguilla  South/Latin America  Global South
# 6                  Albania               Europe  Global North
# 7                  Armenia               Europe  Global South
# 8     Netherlands Antilles  South/Latin America  Global South
# 9                   Angola               Africa  Global South
# 10              Antarctica       Asia & Pacific  Global South
# 11               Argentina  South/Latin America  Global South
# 12          American Samoa       Asia & Pacific  Global South
# ...

# %%
df2=Tabla
new_header = df2.iloc[0] #grab the first row for the header
df2 = df2[1:] #take the data less the header row
df2.columns = new_header #set the header row as the df header
df2 = df2.rename(columns={'Global South': 'Hemisphere'})
df2.head()
# Out:
# 0               Country               Region    Hemisphere
# 1               Andorra               Europe  Global North
# 2  United Arab Emirates          Arab States  Global South
# 3           Afghanistan       Asia & Pacific  Global South
# 4   Antigua and Barbuda  South/Latin America  Global South
# 5              Anguilla  South/Latin America  Global South

# %%
left = df
right = df2
df3=pd.merge(left, right, on='Country')
print(df3.head())
df4=df3.groupby('Region').sum()
df4
# Out:
# 0              Country Active military Reserve military Paramilitary   Total  \
# 0          Afghanistan          174300                0       148700  323000
# 1              Albania            8000                0          500    8500
# 2              Algeria          130000           150000       187200  467200
# 3               Angola          107000                0        10000  117000
# 4  Antigua and Barbuda             180               80            0     260
#
# 0 Per 1000 capita(total) Per 1000 capita(active)               Region  \
# 0                    9.5                     5.1       Asia & Pacific
# 1                    2.8                     2.6               Europe
# 2                   11.4                     3.2          Arab States
# 3                      4                     3.7               Africa
# 4                    2.7                     1.9  South/Latin America
#
# 0    Hemisphere
# 0  Global South
# 1  Global North
# 2  Global South
# ...
