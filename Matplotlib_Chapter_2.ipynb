# %% [markdown]
# <a href="https://colab.research.google.com/github/ivonnics/Machine-Learning/blob/master/Matplotlib_Chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plot


def pdf(X, mu, sigma):
	a = 1. / (sigma * numpy.sqrt(2. * numpy.pi))
	b = -1. / (2. * sigma ** 2)
	return a * numpy.exp(b * (X - mu) ** 2)

X = numpy.linspace(-6, 6, 1024)

for i in range(5):
	samples = numpy.random.standard_normal(50)
	mu, sigma = numpy.mean(samples), numpy.std(samples)
	plot.plot(X, pdf(X, mu, sigma), color = '.75')

plot.plot(X, pdf(X, 0., 1.), color = 'k')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

A = numpy.random.standard_normal((100, 2))
A += numpy.array((-1, -1))

B = numpy.random.standard_normal((100, 2))
B += numpy.array((1, 1))

plot.scatter(A[:,0], A[:,1], color = '.25')
plot.scatter(B[:,0], B[:,1], color = '.75')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

from google.colab import files
uploaded = files.upload()


label_list = (
	b'Iris-setosa',
	b'Iris-versicolor',
	b'Iris-virginica',
)

def read_label(label):
	return label_list.index(label)

data = numpy.loadtxt(uploaded,
                     delimiter = ',',converters = { 4 : read_label })

color_set = ('.00', '.50', '.25')
color_list = [color_set[int(label)] for label in data[:,4]]

#plot.scatter(data[:,0], data[:,1], color = color_list)
plot.show()
# Out:
#      <input type="file" id="files-d75db84a-c3b8-418f-88c1-72c5e528b540" name="files[]" multiple disabled />
#      <output id="result-d75db84a-c3b8-418f-88c1-72c5e528b540">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: loadtxt: Empty input file: "{}"
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-126bfa7b5983> in <module>()
#      16
#      17 data = numpy.loadtxt(uploaded,
# ---> 18                      delimiter = ',',converters = { 4 : read_label })
#      19
#      20 color_set = ('.00', '.50', '.25')
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1120                     return conv(x.encode("latin1"))
#    1121                 import functools
# -> 1122                 converters[i] = functools.partial(tobytes_first, conv=conv)
#    1123             else:
#    1124                 converters[i] = conv
#
# IndexError: list assignment index out of range

# %%
import numpy
import matplotlib.pyplot as plot

data = numpy.random.standard_normal((100, 2))

plot.scatter(data[:,0], data[:,1], color = '1.0', edgecolor='0.0')
plot.show()

# %%
import matplotlib.pyplot as plot

women_pop = [5., 30., 45., 22.]
men_pop   = [5., 25., 50., 20.]

X = range(4)
plot.barh(X, women_pop, color = '.25')
plot.barh(X, [-value for value in men_pop], color = '.75')
plot.show()

# %%
import random
import matplotlib.pyplot as plot

values = [random.randint(0, 99) for i in range(50)]

color_set = ['.00', '.25', '.50', '.75']
color_list = [color_set[(len(color_set) * val) // 100] for val in values]

plot.bar(range(len(values)), values, color = color_list)
plot.show()

# %%
import random
import matplotlib.pyplot as plot

values = [random.random() for i in range(8)]

color_set = ['.00', '.25', '.50', '.75']
plot.pie(values, colors = color_set)
plot.show()

# %%
import random
import matplotlib.pyplot as plot

values = [random.gauss(0., 1.) for i in range(100)]

b = plot.boxplot(values)
print (b.keys())
for name, line_list in b.iteritems():
	for line in line_list:
		line.set_color('k')

plot.show()
# Out:
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-38690532b7e0> in <module>()
#       6 b = plot.boxplot(values)
#       7 print (b.keys())
# ----> 8 for name, line_list in b.iteritems():
#       9         for line in line_list:
#      10                 line.set_color('k')
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
import numpy
import matplotlib.cm as cm
import matplotlib.pyplot as plot

N = 256
angle  = numpy.linspace(0, 8 * 2 * numpy.pi, N)
radius = numpy.linspace(.5, 1., N)

X = radius * numpy.cos(angle)
Y = radius * numpy.sin(angle)

#plot.scatter(X, Y, c = angle, cmap = cm.hsv)
plot.scatter(X, Y, c = angle, cmap = cm.PuOr)
plot.show()

# %%
import random
import matplotlib.cm as cm
import matplotlib.colors as col
import matplotlib.pyplot as plot

values = [random.randint(0, 99) for i in range(50)]
values.sort()

cmap = cm.ScalarMappable(col.Normalize(0, 99), cm.binary)

plot.bar(range(len(values)), values, color = cmap.to_rgba(values))
plot.show()

# %%
import numpy
import matplotlib.pyplot as plot


def pdf(X, mu, sigma):
	a = 1. / (sigma * numpy.sqrt(2. * numpy.pi))
	b = -1. / (2. * sigma ** 2)
	return a * numpy.exp(b * (X - mu) ** 2)

X = numpy.linspace(-6, 6, 1024)

plot.plot(X, pdf(X, 0., 1.),   color = 'k', linestyle = 'solid')
plot.plot(X, pdf(X, 0.,  .5),  color = 'k', linestyle = 'dashed')
plot.plot(X, pdf(X, 0.,  .25), color = 'k', linestyle = 'dashdot')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

N = 8
A = numpy.random.random(N)
B = numpy.random.random(N)

plot.bar(range(N), A, color = '.75')
plot.bar(range(N), A + B, bottom = A, color = 'r', linestyle = 'dashed')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot


def pdf(X, mu, sigma):
	a = 1. / (sigma * numpy.sqrt(2. * numpy.pi))
	b = -1. / (2. * sigma ** 2)
	return a * numpy.exp(b * (X - mu) ** 2)

X = numpy.linspace(-6, 6, 1024)

for i in range(64):
	samples = numpy.random.standard_normal(50)
	mu, sigma = numpy.mean(samples), numpy.std(samples)
	plot.plot(X, pdf(X, mu, sigma), color = '.75', linewidth = .5)

plot.plot(X, pdf(X, 0., 1.), color = 'k', linewidth = 3.)

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

N = 8
A = numpy.random.random(N)
B = numpy.random.random(N)

plot.bar(range(N), A, color = 'w', hatch = 'x')
plot.bar(range(N), A + B, bottom = A, color = 'w', hatch = '/')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

X = numpy.linspace(0, 6, 1024)
Y1 = numpy.sin(X)
Y2 = numpy.cos(2 * X)

plot.fill_between(X, Y1, Y2, color = '.75')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

A = numpy.random.standard_normal((100, 2))
A += numpy.array((-1, -1))

B = numpy.random.standard_normal((100, 2))
B += numpy.array((1, 1))

plot.scatter(A[:,0], A[:,1], color = 'k', marker = 'x')
plot.scatter(B[:,0], B[:,1], color = 'k', marker = '^')

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

data, label_list = [], []
for line in open('iris.data.txt'):
	tokens = line.split(',')
	data.append([float(s) for s in tokens[:-1]])
	label_list.append(tokens[-1])

data_map = { label : [] for label in set(label_list) }
for point, label in zip(data, label_list):
	data_map[label].append(point)
 
marker_set = ['^', 'x', '.']

for marker, (label, subset) in zip(marker_set, data_map.iteritems()):
	data = numpy.asarray(subset)
	plot.scatter(data[:,0], data[:,1], color = 'k', marker = marker)

plot.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-106df20ae4ce> in <module>()
#       3
#       4 data, label_list = [], []
# ----> 5 for line in open('iris.data.txt'):
#       6         tokens = line.split(',')
#       7         data.append([float(s) for s in tokens[:-1]])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iris.data.txt'

# %%
import numpy
import matplotlib.pyplot as plot

A = numpy.random.standard_normal((100, 2))
A += numpy.array((-1, -1))

B = numpy.random.standard_normal((100, 2))
B += numpy.array((1, 1))

plot.scatter(B[:,0], B[:,1], c = 'k', s = 100.)
plot.scatter(A[:,0], A[:,1], c = 'w', s = 25.)

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

M = numpy.random.standard_normal((1000, 2))
R = numpy.sum(M ** 2, axis = 1)

plot.scatter(M[:, 0], M[:, 1], c = 'r', marker = 's', s = 32. * R)
plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

X = numpy.linspace(-6, 6, 1024)
Y1 = numpy.sinc(X)
Y2 = numpy.sinc(X) + 1

plot.plot(X, Y1, marker = 'o', color = '.75')
plot.plot(X, Y2, marker = 'o', color = 'k', markevery = 32)

plot.show()

# %%
import numpy
import matplotlib.pyplot as plot

X = numpy.linspace(-6, 6, 1024)
Y = numpy.sinc(X)

plot.plot(X, Y,
          linewidth = 3.,
          color = 'k',
          markersize = 9,
          markeredgewidth = 1.5,
          markerfacecolor = '.75',
          markeredgecolor = 'k',
          marker = 'o',
          markevery = 32)

plot.show()

# %%
import numpy
import matplotlib as mpl
from matplotlib import pyplot as plot
from cycler import cycler

mpl.rc('lines', linewidth = 2.)
mpl.rc('axes', facecolor = 'k', edgecolor = 'w')
mpl.rc('xtick', color = 'w')
mpl.rc('ytick', color = 'w')
mpl.rc('text', color = 'w')
mpl.rc('figure', facecolor = 'k', edgecolor ='w')
# ORIGINAL: mpl.rc('axes', color_cycle = ('w', '.5', '.75'))
# New Line:
mpl.rc('axes', prop_cycle=(cycler('color', ['r', 'g'])))
# Taken from: https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/issues/395
mpl.rc('savefig', facecolor = 'k', edgecolor = 'w')
X = numpy.linspace(0, 7, 1024)

plot.plot(X, numpy.sin(X))
plot.plot(X, numpy.cos(X))
plot.show()

# %%
import numpy
import matplotlib.path as mpath
from matplotlib import pyplot as plot

shape_description = [
	( 1.,  2., mpath.Path.MOVETO),
	( 1.,  1., mpath.Path.LINETO),
	( 2.,  1., mpath.Path.LINETO),
	( 2., -1., mpath.Path.LINETO),
	( 1., -1., mpath.Path.LINETO),
  ( 1., -2., mpath.Path.LINETO),
	(-1., -2., mpath.Path.LINETO),
	(-1., -1., mpath.Path.LINETO),
	(-2., -1., mpath.Path.LINETO),
	(-2.,  1., mpath.Path.LINETO),
	(-1.,  1., mpath.Path.LINETO),
	(-1.,  2., mpath.Path.LINETO),
	( 0.,  0., mpath.Path.CLOSEPOLY),
]

u, v, codes = zip(*shape_description)
my_marker = mpath.Path(numpy.asarray((u, v)).T, codes)

data = numpy.random.rand(8, 8)
plot.scatter(data[:,0], data[:, 1], c = 'r', marker = my_marker, s = 64)
plot.show()
