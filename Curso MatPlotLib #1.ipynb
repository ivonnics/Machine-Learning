# %% [markdown]
# ## Tomado de este [artículo](https://www.kaggle.com/residentmario/welcome-to-data-visualization)
# [Y de este artículo](https://www.kaggle.com/residentmario/univariate-plotting-with-pandas/data)

# %%
import pandas as pd
reviews = pd.read_csv('C:\\Users\\ivonnics\\Documents\\JOSE LUIS\\Cursos Cursera\\Machine Learning\\winemag-data_first150k.csv', index_col=0)
reviews.head(3)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
#
#          region_1 region_2             variety                   winery
# 0     Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1            Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2  Knights Valley   Sonoma     Sauvignon Blanc                 Macauley

# %% [markdown]
# ## Bar charts and categorical data

# %%
reviews['province'].value_counts().head(10)
# Out:
# California          44508
# Washington           9750
# Tuscany              7281
# Bordeaux             6111
# Northern Spain       4892
# Mendoza Province     4742
# Oregon               4589
# Burgundy             4308
# Piedmont             4093
# Veneto               3962
# Name: province, dtype: int64

# %%
reviews['province'].value_counts().head(10).plot.bar()

# %%
# Para determinar porcentaje:
(reviews['province'].value_counts().head(10) / len(reviews)).plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %% [markdown]
# ## Line charts

# %%
reviews['points'].value_counts().sort_index().plot.line()

# %% [markdown]
# ## Area charts

# %%
reviews['points'].value_counts().sort_index().plot.area()

# %% [markdown]
# ## Interval data
# ### Histograms

# %%
reviews[reviews['price'] < 10]['price'].plot.hist()

# %%
reviews['price'].plot.hist()

# %%
reviews[reviews['price'] > 1500]
# Out:
#       country                                        description  \
# 13318      US  The nose on this single-vineyard wine from a s...
# 34920  France  A big, powerful wine that sums up the richness...
# 34922  France  A massive wine for Margaux, packed with tannin...
#
#                designation  points   price    province     region_1  \
# 13318  Roger Rose Vineyard      91  2013.0  California  Arroyo Seco
# 34920                  NaN      99  2300.0    Bordeaux     Pauillac
# 34922                  NaN      98  1900.0    Bordeaux      Margaux
#
#             region_2                   variety           winery
# 13318  Central Coast                Chardonnay            Blair
# 34920            NaN  Bordeaux-style Red Blend   Château Latour
# 34922            NaN  Bordeaux-style Red Blend  Château Margaux

# %%
reviews[reviews['price'] > 1500]['price'].plot.hist()

# %%
reviews['points'].plot.hist()

# %%
reviews[reviews['points'] > 97]['points'].plot.hist()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

n_bins = 10
x = np.random.randn(1000, 3)

fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show()

# %% [markdown]
# De este [artículo](https://www.kaggle.com/residentmario/bivariate-plotting-with-pandas)
# ## Scatter plot

# %%
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price', y='points')

# %%
reviews[reviews['price'] < 100].plot.scatter(x='price', y='points')

# %% [markdown]
# ## Hexplot

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %% [markdown]
# ## Stacked plots

# %%
wine_counts = pd.read_csv('C:\\Users\\ivonnics\\Documents\\JOSE LUIS\\Cursos Cursera\\Machine Learning\\top 20.csv',
                          index_col=0)
print(wine_counts.head())
wine_counts.drop(['Unnamed: 6'],axis=1,inplace=True)
print(type(wine_counts))
print(wine_counts.head())
# Out:
#         Bordeaux-style Red Blend  Cabernet Sauvignon  Chardonnay  Pinot Noir  \
# points
# 80                           5.0                  87        68.0          36
# 81                          18.0                 159       150.0          83
# 82                          72.0                 435       517.0         295
# 83                          95.0                 570       669.0         346
# 84                         268.0                 923      1146.0         733
#
#         Red Blend  Unnamed: 6
# points
# 80             72         NaN
# 81            107         NaN
# 82            223         NaN
# 83            364         NaN
# 84            602         NaN
# <class 'pandas.core.frame.DataFrame'>
#         Bordeaux-style Red Blend  Cabernet Sauvignon  Chardonnay  Pinot Noir  \
# points
# 80                           5.0                  87        68.0          36
# 81                          18.0                 159       150.0          83
# ...

# %%
wine_counts.plot.bar(stacked=True)

# %%
wine_counts.plot.area()

# %% [markdown]
# ## Bivariate line chart

# %%
wine_counts.plot.line()

# %% [markdown]
# De este [artículo](https://www.kaggle.com/residentmario/styling-your-plots/)
# ## Points on style

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.bar(figsize=(12, 6))

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred')

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16)

# %%
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16,
    title='Rankings Given by Wine Magazine',
)

# %%
import matplotlib.pyplot as plt

ax = reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16
)
ax.set_title("Rankings Given by Wine Magazine", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Rankings Given by Wine Magazine')

# %%
# Sin marco:
import matplotlib.pyplot as plt
import seaborn as sns

ax = reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16
)
ax.set_title("Rankings Given by Wine Magazine", fontsize=20)
sns.despine(bottom=True, left=True)

# %% [markdown]
# De este [artículo](https://www.kaggle.com/residentmario/subplots/https://www.kaggle.com/residentmario/subplots/)
# ## Subplots

# %%
import matplotlib.pyplot as plt
fig, axarr = plt.subplots(2, 3, figsize=(12, 10))

# %%
axarr
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000E4A45E9B0>,
# ...
#       dtype=object)

# %%
fig, axarr = plt.subplots(2, 1, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0]
)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1]
)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

# %%
axarr
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000E4B6BE6D8>,
# ...
#       dtype=object)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0][0]
)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1][1]
)

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0][0], fontsize=12, color='mediumvioletred'
)
axarr[0][0].set_title("Wine Scores", fontsize=18)

reviews['variety'].value_counts().head(20).plot.bar(
    ax=axarr[1][0], fontsize=12, color='mediumvioletred'
)
axarr[1][0].set_title("Wine Varieties", fontsize=18)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1][1], fontsize=12, color='mediumvioletred'
)
axarr[1][1].set_title("Wine Origins", fontsize=18)

reviews['price'].value_counts().plot.hist(
    ax=axarr[0][1], fontsize=12, color='mediumvioletred'
)
axarr[0][1].set_title("Wine Prices", fontsize=18)

plt.subplots_adjust(hspace=.3)

import seaborn as sns
sns.despine()

# %% [markdown]
# De este [artículo](https://www.kaggle.com/residentmario/multivariate-plotting)
# ## Multivariate plotting

# %% [markdown]
# ## [Bubble plot](https://python-graph-gallery.com/bubble-plot/)
# ### Basic Bubble plot

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
# create data
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)
 
# use the scatter function
plt.scatter(x, y, s=z*1000, alpha=0.5)
#plt.scatter(x, y, s=z*1000)
#plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Custom your bubble plot
# ### Color

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
# create data
x = np.random.rand(5)
y = np.random.rand(5)
z = np.random.rand(5)
 
# Change color with c and alpha
plt.scatter(x, y, s=z*4000, c="red", alpha=0.4)
#plt.show()

# %%
#Shape
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
# create data
x = np.random.rand(5)
y = np.random.rand(5)
z = np.random.rand(5)
 
# Change shape with marker
plt.scatter(x, y, s=z*4000, marker="D")
#plt.show()

# %%
#Global size
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
# create data
x = np.random.rand(5)
y = np.random.rand(5)
z = np.random.rand(5)
 
# Change global size playing with s
plt.scatter(x, y, s=z*200)
#plt.savefig('PNG/#271_Bubble_plot_customization3.png', dpi=96)
#plt.clf()
plt.show()

# %%
#Edges
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
# create data
#x = np.random.rand(5)
x=['Lunes','Martes','Miércoles','Jueves','Viernes','Sábado','Domingo']
#y=[.2,.4,.6,.8,1]
y = np.random.rand(7)
y1=np.random.rand(7)
y2=np.random.rand(7)
z = np.random.rand(7)
z1 = np.random.rand(7)
z2 = np.random.rand(7)
 
# Change line around dot
plt.scatter(x, y, s=z*4000, c="green", alpha=0.4, linewidth=6)
plt.scatter(x, y1, s=z1*4000, c="orange", alpha=0.4, linewidth=6)
plt.scatter(x, y2, s=z2*4000, c="red", alpha=0.4, linewidth=6)
#plt.savefig('PNG/#271_Bubble_plot_customization4.png', dpi=96)
#plt.clf()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 5
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (60 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.scatter(x+1, y+1, s=area/2, c=colors, alpha=0.8)
plt.scatter(x+2, y+2, s=area*2, c=colors, alpha=0.8)
plt.show()
