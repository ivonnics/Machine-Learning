# %% [markdown]
# <a href="https://colab.research.google.com/github/ivonnics/Machine-Learning/blob/master/Pandas_Basic_and_Hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taken from:
#
# https://towardsdatascience.com/pandas-from-basic-to-advanced-for-data-scientists-aee4eed19cfe

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/gsampath127/Pandas/master/weather.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df[['temperature','day']]
# Out:
#     temperature       day
# 0            32  1/1/2017
# 1            36  1/2/2017
# 2            28  1/3/2017
# 3            33  1/4/2017
# 4            90  1/1/2017
# 5            85  1/2/2017
# 6            87  1/3/2017
# 7            92  1/4/2017
# 8            45  1/1/2017
# 9            50  1/2/2017
# 10           54  1/3/2017
# 11           42  1/4/2017

# %%
df.rename(columns = {'temperature': 'temp', 'event':'eventtype'})
# Out:
#          day      city  temp  windspeed eventtype
# 0   1/1/2017  new york    32          6      Rain
# 1   1/2/2017  new york    36          7     Sunny
# 2   1/3/2017  new york    28         12      Snow
# 3   1/4/2017  new york    33          7     Sunny
# 4   1/1/2017    mumbai    90          5     Sunny
# 5   1/2/2017    mumbai    85         12       Fog
# 6   1/3/2017    mumbai    87         15       Fog
# 7   1/4/2017    mumbai    92          5      Rain
# 8   1/1/2017     paris    45         20     Sunny
# 9   1/2/2017     paris    50         13    Cloudy
# 10  1/3/2017     paris    54          8    Cloudy
# 11  1/4/2017     paris    42         10    Cloudy

# %%
df[['day','city']][df.event=='Sunny']
# Out:
#         day      city
# 1  1/2/2017  new york
# 3  1/4/2017  new york
# 4  1/1/2017    mumbai
# 8  1/1/2017     paris

# %%
city_group = df.groupby('city')

# %%
city_group.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
df.groupby('city').agg({'temperature':'mean', 'windspeed':'mean'})
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
df1 = pd.DataFrame({
 'city': ['new york','florida','mumbai'],
 'temperature': [22,37,35],
})
df2 = pd.DataFrame({
 'city': ['chicago','new york','florida'],
 'humidity': [65,68,75],
})

# %%
pd.merge(df1,df2,on='city')
# Out:
#        city  temperature  humidity
# 0  new york           22        68
# 1   florida           37        75

# %%
pd.merge(df1,df2,on='city',how='outer')
# Out:
#        city  temperature  humidity
# 0  new york         22.0      68.0
# 1   florida         37.0      75.0
# 2    mumbai         35.0       NaN
# 3   chicago          NaN      65.0

# %%
pd.crosstab(df.city,df.event)
# Out:
# event     Cloudy  Fog  Rain  Snow  Sunny
# city
# mumbai         0    2     1     0      1
# new york       0    0     1     1      2
# paris          3    0     0     0      1

# %%
pd.melt(df,id_vars=['day','city','event'],var_name='attribute')
# Out:
#          day      city   event    attribute  value
# 0   1/1/2017  new york    Rain  temperature     32
# 1   1/2/2017  new york   Sunny  temperature     36
# 2   1/3/2017  new york    Snow  temperature     28
# 3   1/4/2017  new york   Sunny  temperature     33
# 4   1/1/2017    mumbai   Sunny  temperature     90
# 5   1/2/2017    mumbai     Fog  temperature     85
# 6   1/3/2017    mumbai     Fog  temperature     87
# 7   1/4/2017    mumbai    Rain  temperature     92
# 8   1/1/2017     paris   Sunny  temperature     45
# 9   1/2/2017     paris  Cloudy  temperature     50
# 10  1/3/2017     paris  Cloudy  temperature     54
# 11  1/4/2017     paris  Cloudy  temperature     42
# 12  1/1/2017  new york    Rain    windspeed      6
# 13  1/2/2017  new york   Sunny    windspeed      7
# 14  1/3/2017  new york    Snow    windspeed     12
# 15  1/4/2017  new york   Sunny    windspeed      7
# 16  1/1/2017    mumbai   Sunny    windspeed      5
# 17  1/2/2017    mumbai     Fog    windspeed     12
# 18  1/3/2017    mumbai     Fog    windspeed     15
# 19  1/4/2017    mumbai    Rain    windspeed      5
# 20  1/1/2017     paris   Sunny    windspeed     20
# 21  1/2/2017     paris  Cloudy    windspeed     13
# 22  1/3/2017     paris  Cloudy    windspeed      8
# 23  1/4/2017     paris  Cloudy    windspeed     10

# %% [markdown]
# Taken from: https://towardsdatascience.com/hypothesis-testing-in-machine-learning-using-python-a0dc89e169ce
#
# and
#
# https://github.com/yug95/MachineLearning

# %%
import pandas as pd
from scipy import stats
df = pd.read_csv("https://raw.githubusercontent.com/yug95/MachineLearning/master/Hypothesis%20testing/blood_pressure.csv")
df[['bp_before','bp_after']].describe()
ttest,pval = stats.ttest_rel(df['bp_before'], df['bp_after'])
print(pval)
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.0011297914644840823
# reject null hypothesis

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests
ztest ,pval = stests.ztest(df['bp_before'], x2=None, value=156)
print(float(pval))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.6651614730255063
# accept null hypothesis

# %%
ztest ,pval1 = stests.ztest(df['bp_before'], x2=df['bp_after'], value=0,alternative='two-sided')
print(float(pval1))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.002162306611369422
# accept null hypothesis

# %%
df_anova = pd.read_csv('https://raw.githubusercontent.com/yug95/MachineLearning/master/Hypothesis%20testing/PlantGrowth.csv')
df_anova = df_anova[['weight','group']]
grps = pd.unique(df_anova.group.values)
d_data = {grp:df_anova['weight'][df_anova.group == grp] for grp in grps}
 
F, p = stats.f_oneway(d_data['ctrl'], d_data['trt1'], d_data['trt2'])
print("p-value for significance is: ", p)
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# p-value for significance is:  0.0159099583256229
# reject null hypothesis

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
df_anova2 = pd.read_csv("https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/crop_yield.csv")
model = ols('Yield ~ C(Fert)*C(Water)', df_anova2).fit()
print(f"Overall model F({model.df_model: .0f},{model.df_resid: .0f}) = {model.fvalue: .3f}, p = {model.f_pvalue: .4f}")
res = sm.stats.anova_lm(model, typ= 2)
res
# Out:
# Overall model F( 3, 16) =  4.112, p =  0.0243
#                    sum_sq    df         F    PR(>F)
# C(Fert)            69.192   1.0  5.766000  0.028847
# C(Water)           63.368   1.0  5.280667  0.035386
# C(Fert):C(Water)   15.488   1.0  1.290667  0.272656
# Residual          192.000  16.0       NaN       NaN

# %%
df_chi = pd.read_csv('https://raw.githubusercontent.com/yug95/MachineLearning/master/Hypothesis%20testing/chi-test.csv')
df_chi.rename(columns={"Like Shopping?": "Shopping"},inplace=True)
print(df_chi.head(2))
contingency_table=pd.crosstab(df_chi["Gender"],df_chi["Shopping"])
print('contingency_table :-\n',contingency_table)
#Observed Values
Observed_Values = contingency_table.values 
print("Observed Values :-\n",Observed_Values)
b=stats.chi2_contingency(contingency_table)
Expected_Values = b[3]
print("Expected Values :-\n",Expected_Values)
no_of_rows=len(contingency_table.iloc[0:2,0])
no_of_columns=len(contingency_table.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:-",ddof)
alpha = 0.05
from scipy.stats import chi2
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_Values,Expected_Values)])
chi_square_statistic=chi_square[0]+chi_square[1]
print("chi-square statistic:-",chi_square_statistic)
critical_value=chi2.ppf(q=1-alpha,df=ddof)
print('critical_value:',critical_value)
#p-value
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
print('chi-square statistic:',chi_square_statistic)
print('critical_value:',critical_value)
print('p-value:',p_value)
if chi_square_statistic>=critical_value:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
    
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
#    Gender Shopping
# 0    Male       No
# 1  Female      Yes
# contingency_table :-
#  Shopping  No  Yes
# Gender
# Female     2    3
# Male       2    2
# Observed Values :-
#  [[2 3]
#  [2 2]]
# Expected Values :-
#  [[2.22222222 2.77777778]
#  [1.77777778 2.22222222]]
# Degree of Freedom:- 1
# chi-square statistic:- 0.09000000000000008
# critical_value: 3.841458820694124
# p-value: 0.7641771556220945
# Significance level:  0.05
# Degree of Freedom:  1
# chi-square statistic: 0.09000000000000008
# critical_value: 3.841458820694124
# p-value: 0.7641771556220945
# Retain H0,There is no relationship between 2 categorical variables
# Retain H0,There is no relationship between 2 categorical variables
